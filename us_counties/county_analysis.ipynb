# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd

pd.set_option('display.max_columns', None)

# %%
# read the county election data
df = gpd.read_file('data/election/final_data/county_data_with_elections_2012_2016_2020_census_MAIN.geojson')
df_2012 = gpd.read_file('data/election/final_data/county_data_with_elections_2012_census_MAIN.geojson')
df_2016 = gpd.read_file('data/election/final_data/county_data_with_elections_2016_census_MAIN.geojson')
df_2020 = gpd.read_file('data/election/final_data/county_data_with_elections_2020_census_MAIN.geojson')

# %%
# remove commas from the values in all columns
df = df.replace({',': ''}, regex=True)
df_2012 = df_2012.replace({',': ''}, regex=True)
df_2016 = df_2016.replace({',': ''}, regex=True)
df_2020 = df_2020.replace({',': ''}, regex=True)

# %%
def convert_to_number(col):
    try:
        return pd.to_numeric(col)
    except:
        return col
    
df = df.apply(convert_to_number)
df_2012 = df_2012.apply(convert_to_number)
df_2016 = df_2016.apply(convert_to_number)
df_2020 = df_2020.apply(convert_to_number)

# %%
# save the dfs back to geojson
# df.to_file('data/election/final_data/county_data_with_elections_2012_2016_2020_census_MAIN.geojson', driver='GeoJSON')
# df_2012.to_file('data/election/final_data/county_data_with_elections_2012_census_MAIN.geojson', driver='GeoJSON')
# df_2016.to_file('data/election/final_data/county_data_with_elections_2016_census_MAIN.geojson', driver='GeoJSON')
# df_2020.to_file('data/election/final_data/county_data_with_elections_2020_census_MAIN.geojson', driver='GeoJSON')

# %%
# for every column with 'workers' or 'occupation' in the name, append INDUSTRY_ to the beginning of the column name
# this is to make the column names consistent with the other data
for col in df.columns:
    if 'workers' in col or 'occupation' in col:
        df.rename(columns={col: 'INDUSTRY_' + col}, inplace=True)
        df_2012.rename(columns={col: 'INDUSTRY_' + col}, inplace=True)
        df_2016.rename(columns={col: 'INDUSTRY_' + col}, inplace=True)
        df_2020.rename(columns={col: 'INDUSTRY_' + col}, inplace=True)

# %%
df

# %%
# show columns that have pct in the name
total_columns = [col for col in df.columns if 'percent' in col]
print(total_columns)
# Out:
# ['10 to 14 years_percent_2020', '10 to 14 years_percent female_2020', '10 to 14 years_percent male_2020', '15 to 17 years_percent_2020', '15 to 17 years_percent female_2020', '15 to 17 years_percent male_2020', '15 to 19 years_percent_2020', '15 to 19 years_percent female_2020', '15 to 19 years_percent male_2020', '15 to 44 years_percent_2020', '15 to 44 years_percent female_2020', '15 to 44 years_percent male_2020', '16 years and over_percent_2020', '16 years and over_percent female_2020', '16 years and over_percent male_2020', '18 to 24 years_percent_2020', '18 to 24 years_percent female_2020', '18 to 24 years_percent male_2020', '18 years and over_percent_2020', '18 years and over_percent female_2020', '18 years and over_percent male_2020', '20 to 24 years_percent_2020', '20 to 24 years_percent female_2020', '20 to 24 years_percent male_2020', '21 years and over_percent_2020', '21 years and over_percent female_2020', '21 years and over_percent male_2020', '25 to 29 years_percent_2020', '25 to 29 years_percent female_2020', '25 to 29 years_percent male_2020', '30 to 34 years_percent_2020', '30 to 34 years_percent female_2020', '30 to 34 years_percent male_2020', '35 to 39 years_percent_2020', '35 to 39 years_percent female_2020', '35 to 39 years_percent male_2020', '40 to 44 years_percent_2020', '40 to 44 years_percent female_2020', '40 to 44 years_percent male_2020', '45 to 49 years_percent_2020', '45 to 49 years_percent female_2020', '45 to 49 years_percent male_2020', '5 to 14 years_percent_2020', '5 to 14 years_percent female_2020', '5 to 14 years_percent male_2020', '5 to 9 years_percent_2020', '5 to 9 years_percent female_2020', '5 to 9 years_percent male_2020', '50 to 54 years_percent_2020', '50 to 54 years_percent female_2020', '50 to 54 years_percent male_2020', '55 to 59 years_percent_2020', '55 to 59 years_percent female_2020', '55 to 59 years_percent male_2020', '60 to 64 years_percent_2020', '60 to 64 years_percent female_2020', '60 to 64 years_percent male_2020', '60 years and over_percent_2020', '60 years and over_percent female_2020', '60 years and over_percent male_2020', '62 years and over_percent_2020', '62 years and over_percent female_2020', '62 years and over_percent male_2020', '65 to 69 years_percent_2020', '65 to 69 years_percent female_2020', '65 to 69 years_percent male_2020', '65 years and over_percent_2020', '65 years and over_percent female_2020', '65 years and over_percent male_2020', '70 to 74 years_percent_2020', '70 to 74 years_percent female_2020', '70 to 74 years_percent male_2020', '75 to 79 years_percent_2020', '75 to 79 years_percent female_2020', '75 to 79 years_percent male_2020', '75 years and over_percent_2020', '75 years and over_percent female_2020', '75 years and over_percent male_2020', '80 to 84 years_percent_2020', '80 to 84 years_percent female_2020', '80 to 84 years_percent male_2020', '85 years and over_percent_2020', '85 years and over_percent female_2020', '85 years and over_percent male_2020', 'Age_percent_2020', 'Sex_percent_2020', 'Under 18 years_percent_2020', 'Under 18 years_percent female_2020', 'Under 18 years_percent male_2020', 'Under 5 years_percent_2020', 'Under 5 years_percent female_2020', 'Under 5 years_percent male_2020', 'less_than_20_percent_occupied_housing_units_2012', 'less_than_20_percent_owner_occupied_housing_units_2012', 'less_than_20_percent_renter_occupied_housing_units_2012', '20_to_29_percent_occupied_housing_units_2012', '20_to_29_percent_owner_occupied_housing_units_2012', '20_to_29_percent_renter_occupied_housing_units_2012', '30_percent_or_more_occupied_housing_units_2012', '30_percent_or_more_owner_occupied_housing_units_2012', '30_percent_or_more_renter_occupied_housing_units_2012', 'less_than_20_percent_occupied_housing_units_2016', 'less_than_20_percent_owner_occupied_housing_units_2016', 'less_than_20_percent_renter_occupied_housing_units_2016', '20_to_29_percent_occupied_housing_units_2016', '20_to_29_percent_owner_occupied_housing_un ...

# %%
# write all column names to a text file
with open('data/election/final_data/column_names.txt', 'w') as f:
    for col in df.columns:
        f.write(col + '\n')

# %%
df_population_votes = df[['Total population_total_2012', 'Total population_total_2016', 'Total population_total_2020', 'votes_dem_2012', 'votes_gop_2012', 'votes_dem_2016', 'votes_gop_2016', 'votes_dem_2020', 'votes_gop_2020', 'per_dem_2012', 'per_gop_2012', 'per_dem_2016', 'per_gop_2016', 'per_dem_2020', 'per_gop_2020']]

# %%
df_population_votes

# %% [markdown]
# -------

# %% [markdown]
# ##### ML

# %%
elections_demographics_data = df.drop(columns=['geometry'])
elections_demographics_data_2012 = df_2012.drop(columns=['geometry'])
elections_demographics_data_2016 = df_2016.drop(columns=['geometry'])
elections_demographics_data_2020 = df_2020.drop(columns=['geometry'])

# %%
elections_demographics_data = pd.DataFrame(elections_demographics_data)
elections_demographics_data_2012 = pd.DataFrame(elections_demographics_data_2012)
elections_demographics_data_2016 = pd.DataFrame(elections_demographics_data_2016)
elections_demographics_data_2020 = pd.DataFrame(elections_demographics_data_2020)

# %%
elections_demographics_data

# %%
for col in elections_demographics_data.columns:
    if not np.issubdtype(elections_demographics_data[col].dtype, np.number):
        print(col)
# Out:
# per_point_diff_2016
# winner_2012
# winner_2016
# winner_2020
# Child dependency ratio_total_2012
# county_name
# state_name
# state_abbr

# %%
# create a new df from election_demographics_data with only the columns that have dates 2016 and before in the column name (2012, 2016, 2000, 2001, '2008-12', etc)
elections_demographics_data_2016_and_before = elections_demographics_data[[col for col in elections_demographics_data.columns if '2000' in col or '2001' in col or '2002' in col or '2003' in col or '2004' in col or '2005' in col or '2006' in col or '2007' in col or '2008' in col or '2009' in col or '2010' in col or '2011' in col or '2012' in col or '2013' in col or '2014' in col or '2015' in col or '2016' in col or '2008-12' in col]]

# %%
elections_demographics_data_2016_and_before.winner_2016
# Out:
# 0       GOP
# 1       GOP
# 2       GOP
# 3       GOP
# 4       GOP
#        ...
# 3100    GOP
# 3101    DEM
# 3102    GOP
# 3103    GOP
# 3104    GOP
# Name: winner_2016, Length: 3105, dtype: object

# %%
# show valuecounts of column dtypes
elections_demographics_data_2016_and_before.dtypes.value_counts()
# Out:
# float64    799
# int32      133
# object       4
# dtype: int64

# %%
# drop Child dependency ratio_total_2012
elections_demographics_data_2016_and_before = elections_demographics_data_2016_and_before.drop(columns=['Child dependency ratio_total_2012'])

# %%
# scale the data
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
numeric_cols = elections_demographics_data_2016_and_before.select_dtypes(include=[np.number]).columns
elections_demographics_data_2016_and_before[numeric_cols] = scaler.fit_transform(elections_demographics_data_2016_and_before[numeric_cols])

# %%
# drop per_point_diff_2016
elections_demographics_data_2016_and_before = elections_demographics_data_2016_and_before.drop(columns=['per_point_diff_2016'])

# %%
# encode winner_2012 and winner_2016 with GOP = 0 and DEM = 1
elections_demographics_data_2016_and_before['winner_2012'] = elections_demographics_data_2016_and_before['winner_2012'].replace({'GOP': 0, 'DEM': 1})
elections_demographics_data_2016_and_before['winner_2016'] = elections_demographics_data_2016_and_before['winner_2016'].replace({'GOP': 0, 'DEM': 1})

# %%
elections_demographics_data_2016_and_before

# %%
pd.set_option('display.max_rows', 1000)

# %%
# find what values contribute the most to the winner_2016 column
elections_demographics_data_2016_and_before.corr()['winner_2016'].sort_values(ascending=False)
# Out:
# winner_2016                                            1.000000
# per_dem_2016                                           0.770546
# winner_2012                                            0.765184
# per_dem_2012                                           0.682834
# per_point_diff_2012                                    0.682287
#                                                          ...
# white_alone_not_hispanic_or_latino_nonveterans_2012   -0.489716
# white_alone_not_hispanic_or_latino_total_2012         -0.495746
# white_alone_not_hispanic_or_latino_veterans_2012      -0.496979
# per_gop_2012                                          -0.681091
# per_gop_2016                                          -0.761486
# Name: winner_2016, Length: 934, dtype: float64

# %%
# drop all rows with missing values
elections_demographics_data_2016_and_before = elections_demographics_data_2016_and_before.dropna()

# %%
# create columns called win_gop_2012 and win_gop_2016 and win_dem_2012 and win_dem_2016 that are 1 if the GOP or DEM won in 2012 or 2016 and 0 otherwise
elections_demographics_data_2016_and_before['win_gop_2012'] = elections_demographics_data_2016_and_before['winner_2012'].apply(lambda x: 1 if x == 0 else 0)
elections_demographics_data_2016_and_before['win_gop_2016'] = elections_demographics_data_2016_and_before['winner_2016'].apply(lambda x: 1 if x == 0 else 0)
elections_demographics_data_2016_and_before['win_dem_2012'] = elections_demographics_data_2016_and_before['winner_2012'].apply(lambda x: 1 if x == 1 else 0)
elections_demographics_data_2016_and_before['win_dem_2016'] = elections_demographics_data_2016_and_before['winner_2016'].apply(lambda x: 1 if x == 1 else 0)

# %%
# perform a random forest classifier on the data to see which columns are the most important in predicting the win_gop_2016 column
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

X = elections_demographics_data_2016_and_before.drop(columns=['winner_2012', 'winner_2016', 'win_gop_2012', 'win_gop_2016', 'win_dem_2012', 'win_dem_2016', 'per_gop_2012', 'per_gop_2016', 'per_dem_2012', 'per_dem_2016', 'votes_gop_2012', 'votes_gop_2016', 'votes_dem_2012', 'votes_dem_2016', 'per_point_diff_2012'])
y = elections_demographics_data_2016_and_before['winner_2016']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

rf = RandomForestClassifier()
rf.fit(X_train, y_train)

# print accuracy
print(rf.score(X_test, y_test))

importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

# Print the feature ranking formatted so the numbers are all aligned
print("Feature ranking:")
for f in range(X.shape[1]):
    print("%d. %s (%f)" % (f + 1, X.columns[indices[f]], importances[indices[f]]))
# Out:
# 0.9279569892473118
# Feature ranking:
# 1. white_total_2012 (0.036814)
# 2. white_alone_not_hispanic_or_latino_total_2012 (0.033932)
# 3. white_alone_not_hispanic_or_latino_veterans_2012 (0.033182)
# 4. white_alone_not_hispanic_or_latino_nonveterans_2012 (0.030021)
# 5. white_nonveterans_2012 (0.019000)
# 6. black_or_african_american_total_2012 (0.014088)
# 7. black_or_african_american_nonveterans_2012 (0.012829)
# 8. black_or_african_american_veterans_2012 (0.012584)
# 9. Percent of adults with a bachelor's degree or higher, 2000 (0.011185)
# 10. Asian alone_2012 (0.010854)
# 11. 300_to_499_occupied_housing_units_2016 (0.008829)
# 12. Asian_Total_2012 (0.007699)
# 13. 25_to_29_years_Total_2016 (0.007491)
# 14. white_veterans_2012 (0.006913)
# 15. bachelor's_degree_or_higher_nonveterans_2012 (0.006605)
# 16. Percent of adults with a bachelor's degree or higher, 2008-12 (0.006530)
# 17. Percent of adults with a high school diploma only, 2000 (0.006378)
# 18. Asian_alone_Total_2016 (0.006162)
# 19. 300_to_399_occupied_housing_units_2012 (0.006160)
# 20. 30_to_34_years_Total_2016 (0.006134)
# 21. Bachelor's degree or higher, 2008-12 (0.005902)
# 22. Percent of adults with a high school diploma only, 2008-12 (0.005885)
# 23. median_dollars_owner_occupied_housing_units_2012 (0.005360)
# 24. 20_to_24_years_Total_2016 (0.005207)
# 25. diff_2016 (0.005134)
# 26. 2500_to_2999_owner_occupied_housing_units_2016 (0.005061)
# 27. no_cash_rent_renter_occupied_housing_units_2012 (0.005047)
# 28. Bachelor's degree or higher, 2000 (0.004986)
# 29. 2000_to_2499_renter_occupied_housing_units_2020 (0.004668)
# 30. 16_to_19_years_Total_2016 (0.004538)
# 31. asian_alone_total_2016 (0.004525)
# 32. hispanic_or_latino_of_any_race_total_2012 (0.004457)
# 33. Below_poverty_level_Total_2016 (0.004402)
# 34. 200_to_299_owner_occupied_housing_units_2012 (0.004374)
# 35. Black_or_African_American_Total_2012 (0.004319)
# 36. bachelor's_degree_or_higher_total_2012 (0.004307)
# 37. Unemployed_2007 (0.004268)
# 38. high_school_graduate_includes_equivalency_nonveterans_2012 (0.004158)
# 39. Unemployed_2013 (0.004035)
# 40. Employed_2001 (0.004033)
# 41. hispanic_or_latino_of_any_race_nonveterans_2012 (0.004017)
# 42. Age dependency ratio_total_2012 (0.003946)
# 43. 18_to_34_years_nonveterans_2016 (0.003946)
# 44. 20000_to_24999_renter_occupied_housing_units_2020 (0.003770)
# 45. INDUSTRY_Civilian_employed_population_16_years_and_over_pct_natural_resources_construction_maintenance_occupations_2016 (0.003765)
# 46. high_school_graduate_includes_equivalency_total_2012 (0.003666)
# 47. black_or_african_american_alone_total_2016 (0.003635)
# 48. Unemployed_2005 (0.003600)
# 49. income_in_the_past_12_months_below_poverty_level_nonveterans_2016 (0.003587)
# 50. Civilian_labor_force_2013 (0.003470)
# 51. Below_poverty_level_Total_2012 (0.003430)
# 52. Bachelor's_degree_or_higher_Total_2012 (0.003380)
# 53. 20_to_29_percent_owner_occupied_housing_units_2016 (0.003295)
# 54. less_than_20000_renter_occupied_housing_units_2020 (0.003294)
# 55. hispanic_or_latino_of_any_race_veterans_2012 (0.003284)
# 56. unemployment_rate_total_2012 (0.003264)
# 57. Unemployment_rate_2004 (0.003256)
# 58. 18 to 24 years_total_2016 (0.003155)
# 59. asian_nonveterans_2012 (0.003089)
# 60. no_cash_rent_renter_occupied_housing_units_2016 (0.003075)
# 61. asian_alone_veterans_2016 (0.003053)
# 62. Age dependency ratio_total_2016 (0.002913)
# 63. 3000_or_more_owner_occupied_housing_units_2016 (0.002899)
# 64. INDUSTRY_Educational_services_and_health_care_and_social_assistance_total_workers_2016 (0.002763)
# 65. civilian_population_18_years_and_over_with_income_total_2016 (0.002723)
# 66. less_than_20000_occupied_housing_units_2016 (0.002723)
# 67. two_or_more_races_nonveterans_2016 (0.002720)
# 68. Total population_male_2012 (0.002719)
# 69. Population_20_to_64_years_unemployment_rate_2012 (0.002701)
# 70. Unemployed_2006 (0.002695)
# 71. occupied_housing_units_renter_occupied_housing_units_2012 (0.002687)
# 72. 300_to_499_owner_occupied_housing_units_2016 (0.002668)
# 73. Black or African American alone_2012 (0.002656)
# 74. 2500_to_2999_occupied_housing_units_2016 (0.002648)
# 75. Two races including Some other race_2012 (0.002595)
# 76. Child dependency ratio_total_2016 (0.002591)
# 77. asian_alone_nonveterans_2016 (0.002546)
# 78. 50000_to_74999_occupied_housing_units_2016 (0.002503)
# 79. Male_unemployment_rate_2012 (0.002464)
# 80. 20_to_24_years_Total_2012 (0.002444)
# 81. 30_percent_or_more_occupied_housing_units_2016 (0.002439)
# 82. median_dollars_renter_occupied_housing_units_2012 (0.002434)
# 83. unemployment_rate_nonveterans_2012 (0.002394)
# 84. Male_Total_2016 (0.002388)
# 85. Unemployed_2004 (0.002385)
# 86. Less than a high school diploma, 2000 (0.002357)
# 87. less_than_5000_occupied_housing_units_2016 (0.002322)
# 88. with_any_disability_total_2012 (0.002317)
# 89. 20000_to_34999_renter_occupied_housing_units_2020 (0.002317)
# 90. male_nonveterans_2012 (0.002294)
# 91. Sex ratio (males per 100 females)_total_2012 (0.002289)
# 92. Unemployment_rate_2013 (0.002269)
# 93. Two or more races:_2016 (0.002267)
# 94. diff_2012 (0.002215)
# 95. civilian_population_18_years_and_over_total_2016 (0.002209)
# 96. INDUSTRY_Civilian_employed_population_16_years_and_over_pct_natural_resources_construction_maintenance_occupations_2012 (0.002203)
# 97. 2000_or_more_occupied_housing_units_2012 (0.002184)
# 98. Some college or associate's degree, 2000 (0.002162)
# 99. Less_than_high_school_graduate_Total_2016 (0.002158)
# 100. 1500_to_1999_renter_occupied_housing_units_2012 (0.002126)
# 101. civilian_labor_force_18_to_64_years_nonveterans_2012 (0.002125)
# 102. civilian_population_18_to_64_years_total_2016 (0.002106)
# 103. black_or_african_american_alone_nonveterans_2016 (0.002084)
# 104. Male_unemployment_rate_2016 (0.002059)
# 105. Two_or_more_races_Total_2012 (0.002046)
# 106. Unemployed_2003 (0.002008)
# 107. 150000_or_more_owner_occupied_housing_units_2016 (0.002001)
# 108. 15 to 17 years_total_2016 (0.001976)
# 109. Employed_2002 (0.001922)
# 110. some_other_race_veterans_2012 (0.001910)
# 111. occupied_housing_units_renter_occupied_housing_units_2016 (0.001854)
# 112. one_race_total_2012 (0.001812)
# 113. 55 to 59 years_male_2012 (0.001782)
# 114. civilian_population_25_years_and_over_nonveterans_2016 (0.001779)
# 115. Unemployment_rate_2012 (0.001751)
# 116. 18 to 24 years_male_2016 (0.001743)
# 117. 25_to_44_years_unemployment_rate_2012 (0.001725)
# 118. Unemployment_rate_2005 (0.001720)
# 119. 60 to 64 years_total_2016 (0.001620)
# 120. 18_to_34_years_total_2012 (0.001597)
# 121. 20 to 24 years_female_2016 (0.001589)
# 122. 65_to_74_years_total_2012 (0.001585)
# 123. 400_to_499_renter_occupied_housing_units_2012 (0.001574)
# 124. asian_total_2012 (0.001573)
# 125. 16 years and over_total_2012 (0.001572)
# 126. INDUSTRY_Civilian_employed_population_16_years_and_over_pct_service_occupations_2016 (0.001563)
# 127. 18 to 24 years_total_2012 (0.001561)
# 128. 2000_or_more_owner_occupied_housing_units_2012 (0.001522)
# 129. 5 to 9 years_total_2016 (0.001515)
# 130. 200_to_299_occupied_housing_units_2012 (0.001503)
# 131. 400_to_499_occupied_housing_units_2012 (0.001502)
# 132. 30_percent_or_more_owner_occupied_housing_units_2016 (0.001491)
# 133. bachelor's_degree_or_higher_veterans_2012 (0.001489)
# 134. two_or_more_races_nonveterans_2012 (0.001482)
# 135. 10 to 14 years_total_2012 (0.001461)
# 136. 200_to_299_renter_occupied_housing_units_2012 (0.001440)
# 137. 300_to_399_owner_occupied_housing_units_2012 (0.001430)
# 138. INDUSTRY_Public_administration_pct_service_occupations_2012 (0.001421)
# 139. Unemployment_rate_2009 (0.001389)
# 140. At_or_above_the_poverty_level_labor_force_2016 (0.001387)
# 141. 65_to_74_years_veterans_2012 (0.001369)
# 142. Percent of adults with less than a high school diploma, 2000 (0.001361)
# 143. Two races including Some other race_2016 (0.001358)
# 144. median_household_income_dollars_occupied_housing_units_2016 (0.001349)
# 145. zero_or_negative_income_renter_occupied_housing_units_2016 (0.001349)
# 146. INDUSTRY_Civilian_employed_population_16_years_and_over_pct_service_occupations_2012 (0.001346)
# 147. Population_20_to_64_years_unemployment_rate_2016 (0.001335)
# 148. 15 to 44 years_total_2016 (0.001328)
# 149. less_than_20000_occupied_housing_units_2012 (0.001325)
# 150. 65_to_74_years_labor_force_2012 (0.001323)
# 151. White_alone_not_Hispanic_or_Latino_Total_2016 (0.001319)
# 152. less_than_20000_owner_occupied_housing_units_2016 (0.001311)
# 153. 5000_to_9999_occupied_housing_units_2016 (0.001305)
# 154. At_or_above_the_poverty_level_unemployment_rate_2016 (0.001287)
# 155. 18 to 24 years_female_2016 (0.001276)
# 156. Bachelor's_degree_or_higher_employed_2012 (0.001266)
# 157. Unemployment_rate_2007 (0.001264)
# 158. 10 to 14 years_total_2016 (0.001261)
# 159. INDUSTRY_Industry_total_workers_2016 (0.001248)
# 160. some_other_race_nonveterans_2012 (0.001237)
# 161. 1000_to_1499_renter_occupied_housing_units_2012 (0.001230)
# 162. less_than_300_owner_occupied_housing_units_2016 (0.001228)
# 163. 30_percent_or_more_owner_occupied_housing_units_2012 (0.001219)
# 164. Sex ratio (males per 100 females)_total_2016 (0.001217)
# 165. INDUSTRY_Arts_entertainment_and_recreation_and_accommodation_and_food_services_total_workers_2012 (0.001215)
# 166. Percent of adults with less than a high school diploma, 2008-12 (0.001213)
# 167. 1000_to_1499_owner_occupied_housing_units_2012 (0.001210)
# 168. 16 years and over_male_2016 (0.001204)
# 169. 70 to 74 years_female_2012 (0.001192)
# 170. less_than_5000_renter_occupied_housing_units_2012 (0.001183)
# 171. High_school_graduate_includes_equivalency_unemployment_rate_2012 (0.001173)
# 172. Civilian_labor_force_2001 (0.001158)
# 173. 150000_or_more_occupied_housing_units_2012 (0.001152)
# 174. 18 to 24 years_male_2012 (0.001148)
# 175. With_any_disability_unemployment_rate_2016 (0.001145)
# 176. less_than_300_occupied_housing_units_2016 (0.001144)
# 177. White_alone_not_Hispanic_or_Latino_unemployment_rate_2012 (0.001134)
# 178. INDUSTRY_Civilian_employed_population_16_years_and_over_pct_production_transportation_material_moving_occupations_2016 (0.001130)
# 179. 10 to 14 years_female_2012 (0.001126)
# 180. 18_to_34_years_veterans_2016 (0.001126)
# 181. 50000_to_74999_occupied_housing_units_2012 (0.001122)
# 182. Black or African American alone_2016 (0.001118)
# 183. 5 to 14 years_female_2016 (0.001108)
# 184. 5000_to_9999_renter_occupied_housing_units_2012 (0.001104)
# 185. less_than_300_renter_occupied_housing_units_2016 (0.001101)
# 186. With_own_children_under_6_to_17_years_only_unemployment_rate_2016 (0.001100)
# 187. 10000_to_14999_owner_occupied_housing_units_2016 (0.001099)
# 188. 60 years and over_male_2012 (0.001093)
# 189. 16 years and over_male_2012 (0.001093)
# 190. 5000_to_9999_occupied_housing_units_2012 (0.001090)
# 191. Bachelor's_degree_or_higher_Total_2016 (0.001087)
# 192. INDUSTRY_Civilian_employed_population_16_years_and_over_pct_sales_office_occupations_2012 (0.001085)
# 193. American Indian and Alaska Native alone_2016 (0.001080)
# 194. Unemployed_2016 (0.001078)
# 195. 10000_to_14999_occupied_housing_units_2016 (0.001062)
# 196. With_own_children_under_18_years_labor_force_2016 (0.001056)
# 197. bachelor's_degree_or_higher_nonveterans_2016 (0.001052)
# 198. 16 years and over_female_2012 (0.001049)
# 199. 5 to 14 years_female_2012 (0.001047)
# 200. 30_percent_or_more_occupied_housing_units_2012 (0.001043)
# 201. Black_or_African_American_alone_Total_2016 (0.001033)
# 202. 15 to 19 years_male_2016 (0.001032)
# 203. Bachelor's_degree_or_higher_unemployment_rate_2016 (0.001025)
# 204. Unemployment_rate_2010 (0.001019)
# 205. 20 to 24 years_male_2016 (0.001018)
# 206. 20000_to_34999_occupied_housing_units_2012 (0.001015)
# 207. 3000_or_more_occupied_housing_units_2016 (0.001009)
# 208. 2000_to_2499_occupied_housing_units_2016 (0.001002)
# 209. pct_gulf_war_8_1990_to_8_2001_veterans_2020 (0.000994)
# 210. INDUSTRY_Educational_services_and_health_care_and_social_assistance_pct_service_occupations_2012 (0.000988)
# 211. less_than_high_school_graduate_nonveterans_2012 (0.000987)
# 212. 60 years and over_male_2016 (0.000984)
# 213. 20_to_29_percent_owner_occupied_housing_units_2012 (0.000981)
# 214. 500_to_799_occupied_housing_units_2016 (0.000979)
# 215. Unemployed_2002 (0.000977)
# 216. zero_or_negative_income_renter_occupied_housing_units_2012 (0.000977)
# 217. 62 years and over_total_2012 (0.000972)
# 218. INDUSTRY_Agriculture_forestry_fishing_and_hunting_and_mining_total_workers_2012 (0.000969)
# 219. less_than_high_school_graduate_total_2012 (0.000963)
# 220. civilian_population_18_years_and_over_with_income_total_2012 (0.000962)
# 221. INDUSTRY_Educational_services_and_health_care_and_social_assistance_pct_management_business_science_arts_occupations_2012 (0.000962)
# 222. 5 to 14 years_total_2012 (0.000957)
# 223. 10 to 14 years_female_2016 (0.000955)
# 224. 500_to_799_renter_occupied_housing_units_2016 (0.000942)
# 225. Unemployment_rate_2002 (0.000935)
# 226. 500_to_599_renter_occupied_housing_units_2012 (0.000930)
# 227. Some_other_race_alone_Total_2016 (0.000928)
# 228. 25000_to_34999_renter_occupied_housing_units_2012 (0.000926)
# 229. two_or_more_races_total_2012 (0.000922)
# 230. less_than_20000_renter_occupied_housing_units_2012 (0.000922)
# 231. 2000_to_2499_renter_occupied_housing_units_2016 (0.000920)
# 232. 45_to_54_years_unemployment_rate_2012 (0.000918)
# 233. Female_employed_2012 (0.000915)
# 234. High_school_graduate_includes_equivalency_unemployment_rate_2016 (0.000915)
# 235. 20 to 24 years_male_2012 (0.000911)
# 236. 15 to 44 years_total_2012 (0.000907)
# 237. 50000_to_74999_owner_occupied_housing_units_2012 (0.000906)
# 238. 1500_to_1999_occupied_housing_units_2016 (0.000904)
# 239. 16 years and over_total_2016 (0.000902)
# 240. 5 to 9 years_total_2012 (0.000901)
# 241. 15 to 17 years_male_2012 (0.000901)
# 242. 62 years and over_female_2016 (0.000898)
# 243. 2000_to_2499_owner_occupied_housing_units_2016 (0.000898)
# 244. 20000_to_34999_renter_occupied_housing_units_2012 (0.000894)
# 245. At_or_above_the_poverty_level_employed_2016 (0.000893)
# 246. some_other_race_alone_total_2016 (0.000893)
# 247. 18 years and over_total_2016 (0.000893)
# 248. civilian_population_18_years_and_over_with_income_nonveterans_2012 (0.000888)
# 249. 800_to_999_occupied_housing_units_2016 (0.000883)
# 250. 5 to 14 years_total_2016 (0.000876)
# 251. 20_to_24_years_employed_2016 (0.000876)
# 252. 70 to 74 years_male_2012 (0.000874)
# 253. INDUSTRY_Civilian_employed_population_16_years_and_over_pct_production_transportation_material_moving_occupations_2012 (0.000871)
# 254. 65 years and over_male_2012 (0.000871)
# 255. 800_to_999_owner_occupied_housing_units_2016 (0.000871)
# 256. One_race_unemployment_rate_2012 (0.000868)
# 257. civilian_population_18_years_and_over_with_income_nonveterans_2016 (0.000858)
# 258. 20_to_29_percent_occupied_housing_units_2016 (0.000857)
# 259. Age_total_2016 (0.000853)
# 260. 18 years and over_total_2012 (0.000852)
# 261. 18 years and over_male_2012 (0.000838)
# 262. 18 years and over_female_2016 (0.000837)
# 263. INDUSTRY_Wholesale_trade_total_workers_2016 (0.000833)
# 264. 5000_to_9999_owner_occupied_housing_units_2012 (0.000832)
# 265. median_household_income_dollars_renter_occupied_housing_units_2012 (0.000828)
# 266. 25 to 29 years_male_2016 (0.000823)
# 267. Unemployment_rate_2008 (0.000823)
# 268. 60 to 64 years_female_2016 (0.000820)
# 269. 25 to 29 years_total_2016 (0.000818)
# 270. native_hawaiian_and_other_pacific_islander_alone_total_2016 (0.000817)
# 271. 75 to 79 years_male_2016 (0.000816)
# 272. Percent of adults completing some college or associate's degree, 2000 (0.000814)
# 273. american_indian_and_alaska_native_alone_total_2016 (0.000812)
# 274. INDUSTRY_Civilian_employed_population_16_years_and_over_pct_management_business_science_arts_occupations_2016 (0.000812)
# 275. Old-age dependency ratio_total_2012 (0.000811)
# 276. INDUSTRY_Civilian_employed_population_16_years_and_over_pct_sales_office_occupations_2016 (0.000811)
# 277. 500_to_799_owner_occupied_housing_units_2016 (0.000809)
# 278. INDUSTRY_Retail_trade_pct_sales_office_occupations_2016 (0.000803)
# 279. 15 to 17 years_male_2016 (0.000801)
# 280. 40 to 44 years_female_2012 (0.000799)
# 281. INDUSTRY_Public_administration_pct_natural_resources_construction_maintenance_occupations_2012 (0.000798)
# 282. less_than_100_renter_occupied_housing_units_2012 (0.000798)
# 283. 5 to 9 years_male_2016 (0.000797)
# 284. Percent of adults completing some college or associate's degree, 2008-12 (0.000797)
# 285. White_alone_not_Hispanic_or_Latino_Total_2012 (0.000794)
# 286. INDUSTRY_Finance_and_insurance_and_real_estate_and_rental_and_leasing_total_workers_2016 (0.000787)
# 287. less_than_20000_owner_occupied_housing_units_2012 (0.000777)
# 288. Median age (years)_total_2016 (0.000776)
# 289. Civilian_labor_force_2002 (0.000774)
# 290. 65 years and over_total_2016 (0.000772)
# 291. Unemployed_2009 (0.000772)
# 292. 75000_or_more_renter_occupied_housing_units_2012 (0.000771)
# 293. period_of_service_for_the_civilian_veteran_population_18_years_and_over_total_2012 (0.000768)
# 294. Population_16_years_and_over_unemployment_rate_2016 (0.000765)
# 295. 800_to_899_renter_occupied_housing_units_2012 (0.000764)
# 296. Asian alone_2016 (0.000762)
# 297. Unemployed_2010 (0.000760)
# 298. 700_to_799_owner_occupied_housing_units_2012 (0.000758)
# 299. Unemployment_rate_2015 (0.000755)
# 300. 55_to_64_years_total_2012 (0.000753)
# 301. 15 to 19 years_male_2012 (0.000749)
# 302. 40 to 44 years_total_2016 (0.000740)
# 303. less_than_20000_renter_occupied_housing_units_2016 (0.000740)
# 304. 15 to 17 years_total_2012 (0.000740)
# 305. 15 to 17 years_female_2016 (0.000739)
# 306. Some_college_or_associate's_degree_labor_force_2016 (0.000737)
# 307. 75 years and over_total_2012 (0.000735)
# 308. 150000_or_more_renter_occupied_housing_units_2016 (0.000732)
# 309. 1500_to_1999_owner_occupied_housing_units_2016 (0.000732)
# 310. Female_labor_force_2016 (0.000729)
# 311. High_school_graduate_includes_equivalency_labor_force_2012 (0.000729)
# 312. 65 years and over_female_2012 (0.000720)
# 313. 100_to_199_occupied_housing_units_2012 (0.000717)
# 314. veteran_status_for_the_population_18_years_and_over_total_2012 (0.000713)
# 315. 70 to 74 years_total_2016 (0.000708)
# 316. Under 5 years_female_2016 (0.000706)
# 317. 100000_to_149999_occupied_housing_units_2016 (0.000706)
# 318. Employed_2000 (0.000705)
# 319. Bachelor's_degree_or_higher_labor_force_2012 (0.000704)
# 320. 400_to_499_owner_occupied_housing_units_2012 (0.000701)
# 321. gross_rent_renter_occupied_housing_units_2012 (0.000699)
# 322. 15000_to_19999_renter_occupied_housing_units_2012 (0.000697)
# 323. 25 to 29 years_male_2012 (0.000695)
# 324. 80 to 84 years_male_2012 (0.000693)
# 325. 1000_to_1499_owner_occupied_housing_units_2016 (0.000692)
# 326. civilian_labor_force_18_to_64_years_nonveterans_2016 (0.000690)
# 327. INDUSTRY_Educational_services_and_health_care_and_social_assistance_total_workers_2012 (0.000689)
# 328. INDUSTRY_Public_administration_total_workers_2012 (0.000687)
# 329. INDUSTRY_Educational_services_and_health_care_and_social_assistance_pct_production_transportation_material_moving_occupations_2012 (0.000685)
# 330. Economic_typology_2015 (0.000685)
# 331. 1500_to_1999_renter_occupied_housing_units_2016 (0.000684)
# 332. 18_to_34_years_total_2016 (0.000684)
# 333. Population_25_to_64_years_labor_force_2012 (0.000682)
# 334. Some_college_or_associate's_degree_unemployment_rate_2016 (0.000674)
# 335. 10 to 14 years_male_2016 (0.000673)
# 336. 15 to 44 years_male_2012 (0.000673)
# 337. 15 to 44 years_male_2016 (0.000672)
# 338. Male_employed_2016 (0.000671)
# 339. some_other_race_alone_nonveterans_2016 (0.000669)
# 340. Employed_2009 (0.000665)
# 341. 900_to_999_occupied_housing_units_2012 (0.000663)
# 342. INDUSTRY_Educational_services_and_health_care_and_social_assistance_pct_management_business_science_arts_occupations_2016 (0.000663)
# 343. zero_or_negative_income_occupied_housing_units_2016 (0.000659)
# 344. 20_to_24_years_labor_force_2016 (0.000654)
# 345. 1000_to_1499_occupied_housing_units_2016 (0.000654)
# 346. INDUSTRY_Industry_total_workers_2012 (0.000654)
# 347. 20 to 24 years_female_2012 (0.000649)
# 348. 1500_to_1999_owner_occupied_housing_units_2012 (0.000645)
# 349. 75_years_and_over_veterans_2012 (0.000645)
# 350. Female_employed_2016 (0.000643)
# 351. 600_to_699_renter_occupied_housing_units_2012 (0.000642)
# 352. 85 years and over_female_2012 (0.000642)
# 353. Median age (years)_total_2012 (0.000640)
# 354. Less_than_high_school_graduate_employed_2012 (0.000640)
# 355. pct_vietnam_era_veterans_2016 (0.000639)
# 356. Some_college_or_associate's_degree_unemployment_rate_2012 (0.000639)
# 357. 15 to 19 years_total_2012 (0.000638)
# 358. Female_unemployment_rate_2016 (0.000638)
# 359. 2000_or_more_renter_occupied_housing_units_2012 (0.000635)
# 360. 5 to 14 years_male_2012 (0.000635)
# 361. some_other_race_total_2012 (0.000633)
# 362. 75000_or_more_occupied_housing_units_2012 (0.000633)
# 363. 15 to 19 years_total_2016 (0.000632)
# 364. 75000_to_99999_occupied_housing_units_2012 (0.000631)
# 365. Hispanic_or_Latino_origin_of_any_race_Total_2012 (0.000629)
# 366. With_own_children_under_18_years_unemployment_rate_2016 (0.000628)
# 367. 100_to_199_owner_occupied_housing_units_2012 (0.000623)
# 368. INDUSTRY_Retail_trade_pct_management_business_science_arts_occupations_2016 (0.000620)
# 369. hispanic_or_latino_of_any_race_total_2016 (0.000619)
# 370. native_hawaiian_and_other_pacific_islander_nonveterans_2012 (0.000618)
# 371. 55_to_64_years_veterans_2012 (0.000618)
# 372. 55 to 59 years_female_2016 (0.000618)
# 373. less_than_20_percent_owner_occupied_housing_units_2012 (0.000614)
# 374. 80 to 84 years_total_2016 (0.000614)
# 375. 20000_to_24999_renter_occupied_housing_units_2016 (0.000613)
# 376. 55_to_59_years_labor_force_2016 (0.000613)
# 377. White_labor_force_2012 (0.000612)
# 378. 65_to_74_years_labor_force_2016 (0.000611)
# 379. 18 years and over_male_2016 (0.000609)
# 380. 500_to_599_owner_occupied_housing_units_2012 (0.000604)
# 381. 45 to 49 years_male_2016 (0.000603)
# 382. 25000_to_34999_owner_occupied_housing_units_2012 (0.000603)
# 383. 55 to 59 years_total_2016 (0.000600)
# 384. 100000_to_149999_owner_occupied_housing_units_2016 (0.000600)
# 385. median_household_income_dollars_occupied_housing_units_2012 (0.000599)
# 386. INDUSTRY_Civilian_employed_population_16_years_and_over_total_workers_2016 (0.000598)
# 387. 50000_to_74999_renter_occupied_housing_units_2016 (0.000596)
# 388. 65 to 69 years_total_2012 (0.000595)
# 389. INDUSTRY_Manufacturing_total_workers_2016 (0.000592)
# 390. less_than_high_school_graduate_veterans_2012 (0.000591)
# 391. 100000_to_149999_owner_occupied_housing_units_2012 (0.000590)
# 392. 75000_or_more_renter_occupied_housing_units_2016 (0.000589)
# 393. two_or_more_races_veterans_2016 (0.000589)
# 394. Population_25_to_64_years_unemployment_rate_2016 (0.000587)
# 395. 20 to 24 years_total_2016 (0.000585)
# 396. one_race_nonveterans_2012 (0.000579)
# 397. INDUSTRY_Public_administration_pct_management_business_science_arts_occupations_2012 (0.000576)
# 398. 30_percent_or_more_renter_occupied_housing_units_2016 (0.000575)
# 399. 700_to_799_occupied_housing_units_2012 (0.000575)
# 400. 35 to 39 years_female_2012 (0.000574)
# 401. Female_labor_force_2012 (0.000574)
# 402. 300_to_499_renter_occupied_housing_units_2016 (0.000570)
# 403. pct_world_war_ii_veterans_2012 (0.000569)
# 404. 15 to 44 years_female_2012 (0.000568)
# 405. 60 to 64 years_male_2016 (0.000567)
# 406. hispanic_or_latino_of_any_race_veterans_2016 (0.000567)
# 407. 35_to_44_years_labor_force_2016 (0.000566)
# 408. civilian_population_18_to_64_years_veterans_2016 (0.000564)
# 409. 45 to 49 years_male_2012 (0.000563)
# 410. 40 to 44 years_total_2012 (0.000560)
# 411. black_or_african_american_alone_veterans_2016 (0.000560)
# 412. Total:_2012 (0.000556)
# 413. 65_to_74_years_nonveterans_2016 (0.000555)
# 414. Some_college_or_associate's_degree_employed_2016 (0.000555)
# 415. INDUSTRY_Agriculture_forestry_fishing_and_hunting_and_mining_total_workers_2016 (0.000555)
# 416. 60_to_64_years_labor_force_2016 (0.000549)
# 417. Under 5 years_male_2012 (0.000548)
# 418. 65_to_74_years_employed_2012 (0.000546)
# 419. Unemployed_2008 (0.000543)
# 420. 35000_to_49999_owner_occupied_housing_units_2016 (0.000543)
# 421. Some_college_or_associate's_degree_employed_2012 (0.000541)
# 422. 75 to 79 years_female_2016 (0.000540)
# 423. Bachelor's_degree_or_higher_labor_force_2016 (0.000540)
# 424. Unemployment_rate_2001 (0.000539)
# 425. 5 to 14 years_male_2016 (0.000538)
# 426. income_in_the_past_12_months_below_poverty_level_total_2016 (0.000535)
# 427. less_than_20_percent_occupied_housing_units_2012 (0.000534)
# 428. 20 to 24 years_total_2012 (0.000533)
# 429. 75 years and over_male_2012 (0.000531)
# 430. Employment_status_for_population_16_years_and_over_Total_2012 (0.000531)
# 431. Population_25_to_64_years_labor_force_2016 (0.000530)
# 432. 75000_or_more_occupied_housing_units_2016 (0.000528)
# 433. 15000_to_19999_occupied_housing_units_2012 (0.000527)
# 434. 55 to 59 years_female_2012 (0.000526)
# 435. INDUSTRY_Educational_services_and_health_care_and_social_assistance_pct_natural_resources_construction_maintenance_occupations_2016 (0.000525)
# 436. 2000_to_2499_owner_occupied_housing_units_2020 (0.000520)
# 437. 40 to 44 years_male_2012 (0.000519)
# 438. High school diploma only, 2000 (0.000517)
# 439. some_college_or_associate's_degree_nonveterans_2012 (0.000516)
# 440. 35000_to_49999_renter_occupied_housing_units_2016 (0.000514)
# 441. monthly_housing_costs_owner_occupied_housing_units_2012 (0.000514)
# 442. 18_to_34_years_nonveterans_2012 (0.000514)
# 443. 60 to 64 years_male_2012 (0.000512)
# 444. American_Indian_and_Alaska_Native_Total_2012 (0.000512)
# 445. 30 to 34 years_male_2016 (0.000511)
# 446. 20000_to_24999_owner_occupied_housing_units_2012 (0.000510)
# 447. 10000_to_14999_renter_occupied_housing_units_2016 (0.000509)
# 448. 25_to_44_years_employed_2012 (0.000508)
# 449. 20000_to_34999_occupied_housing_units_2016 (0.000503)
# 450. 5 to 9 years_female_2012 (0.000503)
# 451. Bachelor's_degree_or_higher_unemployment_rate_2012 (0.000502)
# 452. Population_25_to_64_years_unemployment_rate_2012 (0.000501)
# 453. INDUSTRY_Public_administration_pct_sales_office_occupations_2012 (0.000500)
# 454. no_cash_rent_occupied_housing_units_2012 (0.000499)
# 455. 85 years and over_female_2016 (0.000499)
# 456. With_any_disability_employed_2016 (0.000499)
# 457. 55_to_64_years_labor_force_2012 (0.000497)
# 458. some_college_or_associate's_degree_veterans_2012 (0.000496)
# 459. With_own_children_under_18_years_Total_2016 (0.000496)
# 460. INDUSTRY_Retail_trade_total_workers_2012 (0.000495)
# 461. Population_20_to_64_years_employed_2016 (0.000494)
# 462. 16 years and over_female_2016 (0.000492)
# 463. INDUSTRY_Information_total_workers_2012 (0.000491)
# 464. Unemployed_2011 (0.000490)
# 465. INDUSTRY_Educational_services_and_health_care_and_social_assistance_pct_service_occupations_2016 (0.000488)
# 466. 75000_to_99999_occupied_housing_units_2016 (0.000488)
# 467. Two_or_more_races_Total_2016 (0.000487)
# 468. White alone_2016 (0.000485)
# 469. Population_16_years_and_over_labor_force_2016 (0.000484)
# 470. 75_years_and_over_total_2012 (0.000484)
# 471. 35_to_54_years_veterans_2012 (0.000483)
# 472. White_alone_Total_2016 (0.000483)
# 473. Median age (years)_female_2016 (0.000482)
# 474. 70 to 74 years_total_2012 (0.000482)
# 475. 150000_or_more_owner_occupied_housing_units_2012 (0.000481)
# 476. two_or_more_races_veterans_2012 (0.000481)
# 477. 800_to_899_owner_occupied_housing_units_2012 (0.000478)
# 478. Native Hawaiian and Other Pacific Islander alone_2012 (0.000476)
# 479. civilian_population_18_years_and_over_for_whom_poverty_status_is_determined_veterans_2016 (0.000475)
# 480. 70 to 74 years_female_2016 (0.000473)
# 481. 800_to_899_occupied_housing_units_2012 (0.000473)
# 482. american_indian_and_alaska_native_total_2012 (0.000473)
# 483. 60_to_64_years_employed_2016 (0.000470)
# 484. with_any_disability_nonveterans_2016 (0.000467)
# 485. 55_to_64_years_nonveterans_2012 (0.000466)
# 486. less_than_high_school_graduate_total_2016 (0.000466)
# 487. occupied_housing_units_occupied_housing_units_2016 (0.000466)
# 488. 10000_to_14999_owner_occupied_housing_units_2012 (0.000465)
# 489. one_race_veterans_2012 (0.000464)
# 490. 900_to_999_renter_occupied_housing_units_2012 (0.000463)
# 491. white_alone_veterans_2016 (0.000460)
# 492. 18 to 24 years_female_2012 (0.000459)
# 493. 45_to_54_years_employed_2016 (0.000458)
# 494. 75000_or_more_owner_occupied_housing_units_2012 (0.000457)
# 495. High_school_graduate_includes_equivalency_labor_force_2016 (0.000457)
# 496. pct_world_war_ii_veterans_2016 (0.000456)
# 497. civilian_labor_force_18_to_64_years_veterans_2016 (0.000453)
# 498. Unemployment_rate_2000 (0.000452)
# 499. Unemployment_rate_2006 (0.000451)
# 500. Male_labor_force_2016 (0.000450)
# 501. white_alone_not_hispanic_or_latino_nonveterans_2016 (0.000449)
# 502. income_in_the_past_12_months_at_or_above_poverty_level_veterans_2016 (0.000447)
# 503. With_any_disability_Total_2012 (0.000445)
# 504. 20_to_29_percent_renter_occupied_housing_units_2016 (0.000444)
# 505. 15000_to_19999_owner_occupied_housing_units_2012 (0.000444)
# 506. Male_labor_force_2012 (0.000444)
# 507. white_alone_not_hispanic_or_latino_total_2016 (0.000442)
# 508. INDUSTRY_Retail_trade_pct_natural_resources_construction_maintenance_occupations_2016 (0.000440)
# 509. 45 to 49 years_female_2016 (0.000440)
# 510. 50 to 54 years_total_2012 (0.000440)
# 511. Population_16_years_and_over_labor_force_2012 (0.000439)
# 512. high_school_graduate_includes_equivalency_veterans_2016 (0.000438)
# 513. american_indian_and_alaska_native_nonveterans_2012 (0.000438)
# 514. civilian_population_18_to_64_years_veterans_2012 (0.000438)
# 515. INDUSTRY_Educational_services_and_health_care_and_social_assistance_pct_production_transportation_material_moving_occupations_2016 (0.000436)
# 516. 1000_to_1499_occupied_housing_units_2012 (0.000435)
# 517. 40 to 44 years_female_2016 (0.000435)
# 518. 75000_to_99999_renter_occupied_housing_units_2012 (0.000434)
# 519. 80 to 84 years_male_2016 (0.000433)
# 520. 15000_to_19999_renter_occupied_housing_units_2016 (0.000433)
# 521. 75_years_and_over_Total_2012 (0.000431)
# 522. Some other race alone_2016 (0.000431)
# 523. some_college_or_associate's_degree_total_2012 (0.000430)
# 524. no_cash_rent_occupied_housing_units_2016 (0.000430)
# 525. Unemployed_2015 (0.000430)
# 526. tenure_occupied_housing_units_2012 (0.000429)
# 527. 50 to 54 years_male_2016 (0.000429)
# 528. median_dollars_occupied_housing_units_2012 (0.000427)
# 529. pct_gulf_war_9_2001_or_later_veterans_2020 (0.000425)
# 530. american_indian_and_alaska_native_veterans_2012 (0.000423)
# 531. Female_unemployment_rate_2012 (0.000421)
# 532. Age_total_2012 (0.000420)
# 533. 65 years and over_male_2016 (0.000419)
# 534. INDUSTRY_Transportation_and_warehousing_and_utilities_total_workers_2012 (0.000418)
# 535. american_indian_and_alaska_native_alone_veterans_2016 (0.000418)
# 536. bachelor's_degree_or_higher_total_2016 (0.000418)
# 537. 15000_to_19999_occupied_housing_units_2016 (0.000417)
# 538. American_Indian_and_Alaska_Native_alone_Total_2016 (0.000417)
# 539. Unemployment_rate_2003 (0.000416)
# 540. One_race_employed_2012 (0.000416)
# 541. Under 5 years_male_2016 (0.000414)
# 542. 35 to 39 years_male_2016 (0.000414)
# 543. White_alone_not_Hispanic_or_Latino_employed_2016 (0.000413)
# 544. 35000_to_49999_owner_occupied_housing_units_2012 (0.000411)
# 545. Population_25_to_64_years_Total_2012 (0.000410)
# 546. less_than_5000_owner_occupied_housing_units_2016 (0.000408)
# 547. 55_to_64_years_total_2016 (0.000405)
# 548. civilian_population_18_years_and_over_veterans_2016 (0.000405)
# 549. 25 to 29 years_total_2012 (0.000402)
# 550. pct_korean_war_veterans_2012 (0.000402)
# 551. Under 5 years_total_2012 (0.000401)
# 552. INDUSTRY_Retail_trade_pct_production_transportation_material_moving_occupations_2016 (0.000399)
# 553. 15 to 19 years_female_2012 (0.000399)
# 554. native_hawaiian_and_other_pacific_islander_alone_nonveterans_2016 (0.000399)
# 555. Civilian_labor_force_2009 (0.000399)
# 556. with_any_disability_total_2016 (0.000397)
# 557. 30_percent_or_more_renter_occupied_housing_units_2012 (0.000396)
# 558. 50000_to_74999_owner_occupied_housing_units_2016 (0.000395)
# 559. 10000_to_14999_renter_occupied_housing_units_2012 (0.000395)
# 560. With_own_children_under_6_to_17_years_only_employed_2016 (0.000394)
# 561. With_own_children_under_6_years_Total_2012 (0.000394)
# 562. Unemployed_2001 (0.000394)
# 563. Unemployment_rate_2016 (0.000390)
# 564. 55 to 59 years_total_2012 (0.000390)
# 565. 100000_to_149999_occupied_housing_units_2012 (0.000389)
# 566. civilian_population_25_years_and_over_veterans_2012 (0.000389)
# 567. civilian_population_25_years_and_over_veterans_2016 (0.000388)
# 568. 30 to 34 years_female_2012 (0.000388)
# 569. Native_Hawaiian_and_Other_Pacific_Islander_alone_Total_2016 (0.000386)
# 570. 35_to_44_years_unemployment_rate_2016 (0.000385)
# 571. 25 to 29 years_female_2012 (0.000385)
# 572. Some college or associate's degree, 2008-12 (0.000382)
# 573. 15 to 44 years_female_2016 (0.000380)
# 574. 100_to_199_renter_occupied_housing_units_2012 (0.000380)
# 575. INDUSTRY_Finance_and_insurance_and_real_estate_and_rental_and_leasing_total_workers_2012 (0.000378)
# 576. Civilian_labor_force_2014 (0.000378)
# 577. 75000_to_99999_owner_occupied_housing_units_2016 (0.000377)
# 578. 60 to 64 years_female_2012 (0.000377)
# 579. 1000_to_1499_renter_occupied_housing_units_2016 (0.000376)
# 580. White_alone_not_Hispanic_or_Latino_unemployment_rate_2016 (0.000375)
# 581. Some_other_race_Total_2012 (0.000375)
# 582. Population_20_to_64_years_labor_force_2016 (0.000373)
# 583. 30 to 34 years_male_2012 (0.000373)
# 584. 20000_to_34999_owner_occupied_housing_units_2020 (0.000370)
# 585. 60 years and over_female_2016 (0.000368)
# 586. 20_to_24_years_employed_2012 (0.000368)
# 587. american_indian_and_alaska_native_alone_nonveterans_2016 (0.000367)
# 588. civilian_population_18_years_and_over_for_whom_poverty_status_is_determined_nonveterans_2016 (0.000366)
# 589. Female_Total_2012 (0.000365)
# 590. occupied_housing_units_owner_occupied_housing_units_2012 (0.000365)
# 591. some_other_race_alone_veterans_2016 (0.000365)
# 592. White_alone_not_Hispanic_or_Latino_labor_force_2016 (0.000365)
# 593. 35_to_54_years_total_2012 (0.000364)
# 594. High school diploma only, 2008-12 (0.000363)
# 595. civilian_labor_force_18_to_64_years_veterans_2012 (0.000363)
# 596. 20000_to_24999_renter_occupied_housing_units_2012 (0.000362)
# 597. white_alone_total_2016 (0.000358)
# 598. High_school_graduate_includes_equivalency_employed_2012 (0.000358)
# 599. Unemployment_rate_2011 (0.000358)
# 600. less_than_high_school_graduate_veterans_2016 (0.000358)
# 601. 50000_to_74999_renter_occupied_housing_units_2012 (0.000357)
# 602. high_school_graduate_includes_equivalency_veterans_2012 (0.000355)
# 603. 62 years and over_male_2016 (0.000355)
# 604. white_alone_nonveterans_2016 (0.000353)
# 605. With_own_children_under_18_years_employed_2016 (0.000352)
# 606. Population_20_to_64_years_labor_force_2012 (0.000352)
# 607. 65_to_74_years_veterans_2016 (0.000350)
# 608. 3000_or_more_renter_occupied_housing_units_2016 (0.000349)
# 609. 25000_to_34999_owner_occupied_housing_units_2016 (0.000347)
# 610. 18_to_34_years_veterans_2012 (0.000347)
# 611. 65_to_74_years_employed_2016 (0.000347)
# 612. 55_to_64_years_veterans_2016 (0.000344)
# 613. income_in_the_past_12_months_at_or_above_poverty_level_total_2016 (0.000344)
# 614. 700_to_799_renter_occupied_housing_units_2012 (0.000344)
# 615. INDUSTRY_Educational_services_and_health_care_and_social_assistance_pct_sales_office_occupations_2012 (0.000344)
# 616. female_veterans_2016 (0.000343)
# 617. White_employed_2012 (0.000340)
# 618. Employed_2015 (0.000340)
# 619. 45_to_54_years_employed_2012 (0.000339)
# 620. 50 to 54 years_female_2012 (0.000338)
# 621. hispanic_or_latino_of_any_race_nonveterans_2016 (0.000337)
# 622. civilian_population_18_years_and_over_veterans_2012 (0.000336)
# 623. 20_to_24_years_labor_force_2012 (0.000336)
# 624. Two or more races:_2012 (0.000336)
# 625. INDUSTRY_Information_total_workers_2016 (0.000335)
# 626. 45 to 49 years_total_2016 (0.000335)
# 627. With_any_disability_labor_force_2016 (0.000335)
# 628. 20000_to_24999_occupied_housing_units_2016 (0.000333)
# 629. less_than_20000_occupied_housing_units_2020 (0.000332)
# 630. 60 to 64 years_total_2012 (0.000332)
# 631. labor_force_participation_rate_veterans_2012 (0.000332)
# 632. 85 years and over_total_2012 (0.000331)
# 633. zero_or_negative_income_occupied_housing_units_2012 (0.000331)
# 634. 35_to_54_years_veterans_2016 (0.000330)
# 635. 20000_to_24999_owner_occupied_housing_units_2016 (0.000328)
# 636. 85 years and over_male_2016 (0.000327)
# 637. INDUSTRY_Civilian_employed_population_16_years_and_over_pct_management_business_science_arts_occupations_2012 (0.000326)
# 638. total_votes_2012 (0.000325)
# 639. White_unemployment_rate_2012 (0.000324)
# 640. less_than_5000_owner_occupied_housing_units_2012 (0.000323)
# 641. 75 years and over_female_2016 (0.000323)
# 642. 75_years_and_over_nonveterans_2016 (0.000323)
# 643. 45 to 49 years_female_2012 (0.000322)
# 644. two_or_more_races_total_2016 (0.000321)
# 645. INDUSTRY_Professional_scientific_and_management_and_administrative_and_waste_management_services_total_workers_2012 (0.000320)
# 646. Total population_female_2016 (0.000320)
# 647. Male_employed_2012 (0.000318)
# 648. INDUSTRY_Educational_services_and_health_care_and_social_assistance_pct_sales_office_occupations_2016 (0.000317)
# 649. 50 to 54 years_male_2012 (0.000316)
# 650. Population_25_to_64_years_employed_2016 (0.000315)
# 651. Some other race alone_2012 (0.000314)
# 652. female_total_2016 (0.000314)
# 653. 10 to 14 years_male_2012 (0.000313)
# 654. male_veterans_2016 (0.000313)
# 655. 800_to_999_renter_occupied_housing_units_2016 (0.000313)
# 656. less_than_100_owner_occupied_housing_units_2012 (0.000313)
# 657. Bachelor's_degree_or_higher_employed_2016 (0.000312)
# 658. pct_gulf_war_9_2001_or_later_veterans_2016 (0.000312)
# 659. 25 to 29 years_female_2016 (0.000311)
# 660. 65 years and over_female_2016 (0.000309)
# 661. 80 to 84 years_female_2012 (0.000308)
# 662. 75 years and over_female_2012 (0.000308)
# 663. zero_or_negative_income_owner_occupied_housing_units_2012 (0.000305)
# 664. 35_to_54_years_nonveterans_2012 (0.000305)
# 665. 75_years_and_over_nonveterans_2012 (0.000305)
# 666. 65 to 69 years_male_2016 (0.000304)
# 667. Some_college_or_associate's_degree_labor_force_2012 (0.000304)
# 668. 75 years and over_male_2016 (0.000304)
# 669. INDUSTRY_Public_administration_total_workers_2016 (0.000299)
# 670. Less_than_high_school_graduate_Total_2012 (0.000299)
# 671. Median age (years)_male_2016 (0.000297)
# 672. 900_to_999_owner_occupied_housing_units_2012 (0.000294)
# 673. White alone_2012 (0.000293)
# 674. Less than a high school diploma, 2008-12 (0.000292)
# 675. INDUSTRY_Manufacturing_total_workers_2012 (0.000289)
# 676. 45_to_54_years_labor_force_2016 (0.000289)
# 677. INDUSTRY_Professional_scientific_and_management_and_administrative_and_waste_management_services_total_workers_2016 (0.000288)
# 678. 62 years and over_male_2012 (0.000287)
# 679. 25000_to_34999_renter_occupied_housing_units_2016 (0.000286)
# 680. 65_to_74_years_total_2016 (0.000286)
# 681. white_alone_not_hispanic_or_latino_veterans_2016 (0.000286)
# 682. less_than_5000_occupied_housing_units_2012 (0.000285)
# 683. 20000_to_34999_renter_occupied_housing_units_2016 (0.000284)
# 684. 75 years and over_total_2016 (0.000283)
# 685. pct_gulf_war_8_1990_to_8_2001_veterans_2012 (0.000282)
# 686. 5000_to_9999_renter_occupied_housing_units_2016 (0.000281)
# 687. White_alone_not_Hispanic_or_Latino_labor_force_2012 (0.000280)
# 688. Population_16_years_and_over_unemployment_rate_2012 (0.000280)
# 689. 15 to 19 years_female_2016 (0.000280)
# 690. less_than_20_percent_owner_occupied_housing_units_2016 (0.000278)
# 691. 62 years and over_female_2012 (0.000278)
# 692. 75000_to_99999_owner_occupied_housing_units_2012 (0.000276)
# 693. Less_than_high_school_graduate_labor_force_2012 (0.000276)
# 694. White_Total_2012 (0.000276)
# 695. 35 to 39 years_female_2016 (0.000275)
# 696. INDUSTRY_Transportation_and_warehousing_and_utilities_total_workers_2016 (0.000274)
# 697. 80 to 84 years_female_2016 (0.000274)
# 698. high_school_graduate_includes_equivalency_nonveterans_2016 (0.000273)
# 699. pct_gulf_war_9_2001_or_later_veterans_2012 (0.000273)
# 700. Civilian_labor_force_2012 (0.000272)
# 701. INDUSTRY_Retail_trade_pct_service_occupations_2016 (0.000272)
# 702. 10000_to_14999_occupied_housing_units_2012 (0.000272)
# 703. Civilian_labor_force_2003 (0.000271)
# 704. 65 to 69 years_female_2012 (0.000271)
# 705. 40 to 44 years_male_2016 (0.000270)
# 706. 5 to 9 years_female_2016 (0.000269)
# 707. 75 to 79 years_male_2012 (0.000269)
# 708. 20000_to_24999_owner_occupied_housing_units_2020 (0.000269)
# 709. Civilian_labor_force_2016 (0.000268)
# 710. Some_college_or_associate's_degree_Total_2016 (0.000266)
# 711. 70 to 74 years_male_2016 (0.000265)
# 712. 18 years and over_female_2012 (0.000264)
# 713. below_poverty_in_the_past_12_months_total_2012 (0.000261)
# 714. 75000_or_more_owner_occupied_housing_units_2016 (0.000261)
# 715. male_total_2016 (0.000258)
# 716. 45_to_54_years_Total_2012 (0.000258)
# 717. 150000_or_more_renter_occupied_housing_units_2012 (0.000257)
# 718. 35 to 39 years_total_2016 (0.000257)
# 719. INDUSTRY_Arts_entertainment_and_recreation_and_accommodation_and_food_services_total_workers_2016 (0.000257)
# 720. pct_korean_war_veterans_2016 (0.000256)
# 721. 65 to 69 years_female_2016 (0.000256)
# 722. 65 years and over_total_2012 (0.000253)
# 723. With_own_children_under_6_to_17_years_only_labor_force_2016 (0.000253)
# 724. female_nonveterans_2012 (0.000252)
# 725. 75000_to_99999_renter_occupied_housing_units_2016 (0.000251)
# 726. 16_to_19_years_Total_2012 (0.000250)
# 727. 15000_to_19999_owner_occupied_housing_units_2016 (0.000250)
# 728. 55_to_59_years_unemployment_rate_2016 (0.000249)
# 729. civilian_population_25_years_and_over_total_2012 (0.000248)
# 730. 85 years and over_male_2012 (0.000248)
# 731. 50 to 54 years_female_2016 (0.000248)
# 732. 60_to_64_years_unemployment_rate_2016 (0.000248)
# 733. 65 to 69 years_male_2012 (0.000245)
# 734. Population_20_to_64_years_Total_2012 (0.000245)
# 735. Employed_2008 (0.000245)
# 736. 45_to_54_years_labor_force_2012 (0.000244)
# 737. 60_to_64_years_Total_2016 (0.000243)
# 738. civilian_population_25_years_and_over_total_2016 (0.000241)
# 739. White_alone_employed_2016 (0.000240)
# 740. less_than_20_percent_renter_occupied_housing_units_2016 (0.000240)
# 741. less_than_20_percent_renter_occupied_housing_units_2012 (0.000240)
# 742. total_votes_2016 (0.000239)
# 743. less_than_20_percent_occupied_housing_units_2016 (0.000239)
# 744. pct_vietnam_era_veterans_2012 (0.000238)
# 745. 5000_to_9999_owner_occupied_housing_units_2016 (0.000238)
# 746. Sex_total_2012 (0.000236)
# 747. Unemployment_rate_2014 (0.000236)
# 748. median_dollars_occupied_housing_units_2016 (0.000236)
# 749. high_school_graduate_includes_equivalency_total_2016 (0.000231)
# 750. 45 to 49 years_total_2012 (0.000231)
# 751. 100000_to_149999_renter_occupied_housing_units_2016 (0.000231)
# 752. Metro_2013 (0.000230)
# 753. 20_to_29_percent_occupied_housing_units_2012 (0.000230)
# 754. some_college_or_associate's_degree_veterans_2016 (0.000226)
# 755. 55_to_64_years_unemployment_rate_2012 (0.000226)
# 756. 5 to 9 years_male_2012 (0.000226)
# 757. less_than_20000_owner_occupied_housing_units_2020 (0.000225)
# 758. with_any_disability_veterans_2016 (0.000225)
# 759. Native_Hawaiian_and_Other_Pacific_Islander_Total_2012 (0.000225)
# 760. American Indian and Alaska Native alone_2012 (0.000225)
# 761. 80 to 84 years_total_2012 (0.000222)
# 762. 600_to_699_occupied_housing_units_2012 (0.000221)
# 763. Population_16_years_and_over_Total_2016 (0.000219)
# 764. Employed_2003 (0.000219)
# 765. less_than_5000_renter_occupied_housing_units_2016 (0.000218)
# 766. civilian_population_18_years_and_over_nonveterans_2016 (0.000218)
# 767. income_in_the_past_12_months_below_poverty_level_veterans_2016 (0.000217)
# 768. without_a_disability_nonveterans_2016 (0.000216)
# 769. asian_veterans_2012 (0.000216)
# 770. 25000_to_34999_occupied_housing_units_2016 (0.000216)
# 771. 150000_or_more_occupied_housing_units_2016 (0.000215)
# 772. 75 to 79 years_female_2012 (0.000214)
# 773. With_own_children_under_6_years_and_6_to_17_years_Total_2016 (0.000212)
# 774. Total population_total_2012 (0.000211)
# 775. 55_to_59_years_Total_2016 (0.000210)
# 776. INDUSTRY_Construction_total_workers_2016 (0.000210)
# 777. 75_years_and_over_Total_2016 (0.000210)
# 778. male_nonveterans_2016 (0.000209)
# 779. Two races excluding Some other race, and three or more races_2016 (0.000208)
# 780. 20000_to_24999_occupied_housing_units_2012 (0.000205)
# 781. With_own_children_under_6_to_17_years_only_Total_2016 (0.000204)
# 782. INDUSTRY_Wholesale_trade_total_workers_2012 (0.000203)
# 783. labor_force_participation_rate_total_2012 (0.000202)
# 784. Civilian_labor_force_2006 (0.000201)
# 785. 60 years and over_total_2012 (0.000201)
# 786. Total population_total_2016 (0.000200)
# 787. 75_years_and_over_total_2016 (0.000200)
# 788. Civilian_labor_force_2010 (0.000199)
# 789. 25_to_44_years_Total_2012 (0.000198)
# 790. 55_to_64_years_Total_2012 (0.000198)
# 791. Civilian_labor_force_2000 (0.000198)
# 792. 35000_to_49999_renter_occupied_housing_units_2012 (0.000196)
# 793. 500_to_599_occupied_housing_units_2012 (0.000196)
# 794. 62 years and over_total_2016 (0.000193)
# 795. INDUSTRY_Other_services_except_public_administration_total_workers_2012 (0.000192)
# 796. 300_to_399_renter_occupied_housing_units_2012 (0.000192)
# 797. 60 years and over_female_2012 (0.000191)
# 798. 35 to 39 years_total_2012 (0.000190)
# 799. White_alone_not_Hispanic_or_Latino_employed_2012 (0.000189)
# 800. White_alone_labor_force_2016 (0.000188)
# 801. Two races excluding Some other race, and three or more races_2012 (0.000188)
# 802. income_in_the_past_12_months_at_or_above_poverty_level_nonveterans_2016 (0.000187)
# 803. Civilian_labor_force_2007 (0.000186)
# 804. 600_to_699_owner_occupied_housing_units_2012 (0.000186)
# 805. 25_to_44_years_labor_force_2012 (0.000185)
# 806. Old-age dependency ratio_total_2016 (0.000184)
# 807. 20000_to_34999_owner_occupied_housing_units_2016 (0.000184)
# 808. INDUSTRY_Civilian_employed_population_16_years_and_over_total_workers_2012 (0.000182)
# 809. civilian_population_18_to_64_years_nonveterans_2012 (0.000178)
# 810. White_alone_unemployment_rate_2016 (0.000177)
# 811. One_race_Total_2012 (0.000177)
# 812. 75 to 79 years_total_2016 (0.000175)
# 813. median_household_income_dollars_owner_occupied_housing_units_2012 (0.000175)
# 814. 45_to_54_years_Total_2016 (0.000173)
# 815. 20000_to_34999_occupied_housing_units_2020 (0.000172)
# 816. Population_20_to_64_years_employed_2012 (0.000171)
# 817. 35000_to_49999_occupied_housing_units_2016 (0.000171)
# 818. 65_to_74_years_Total_2012 (0.000170)
# 819. Civilian_labor_force_2005 (0.000169)
# 820. 45_to_54_years_unemployment_rate_2016 (0.000167)
# 821. Native Hawaiian and Other Pacific Islander alone_2016 (0.000166)
# 822. Under 5 years_female_2012 (0.000166)
# 823. 65_to_74_years_Total_2016 (0.000166)
# 824. Total:_2016 (0.000166)
# 825. 85 years and over_total_2016 (0.000165)
# 826. Population_25_to_64_years_employed_2012 (0.000164)
# 827. pct_gulf_war_8_1990_to_8_2001_veterans_2016 (0.000162)
# 828. 55_to_64_years_employed_2012 (0.000159)
# 829. Population_16_years_and_over_employed_2012 (0.000159)
# 830. High_school_graduate_includes_equivalency_Total_2012 (0.000157)
# 831. Some_college_or_associate's_degree_Total_2012 (0.000154)
# 832. occupied_housing_units_owner_occupied_housing_units_2016 (0.000152)
# 833. Hispanic_or_Latino_origin_of_any_race_Total_2016 (0.000152)
# 834. INDUSTRY_Educational_services_and_health_care_and_social_assistance_pct_natural_resources_construction_maintenance_occupations_2012 (0.000151)
# 835. Civilian_labor_force_2011 (0.000149)
# 836. 35_to_54_years_total_2016 (0.000149)
# 837. 1500_to_1999_occupied_housing_units_2012 (0.000148)
# 838. 100000_to_149999_renter_occupied_housing_units_2012 (0.000147)
# 839. 30 to 34 years_total_2012 (0.000147)
# 840. 65_to_74_years_nonveterans_2012 (0.000147)
# 841. 75 to 79 years_total_2012 (0.000144)
# 842. One_race_labor_force_2012 (0.000142)
# 843. Sex_total_2016 (0.000141)
# 844. Population_16_years_and_over_employed_2016 (0.000141)
# 845. labor_force_participation_rate_nonveterans_2012 (0.000140)
# 846. 30 to 34 years_female_2016 (0.000139)
# 847. without_a_disability_total_2016 (0.000137)
# 848. 2000_to_2499_occupied_housing_units_2020 (0.000137)
# 849. less_than_high_school_graduate_nonveterans_2016 (0.000136)
# 850. Employed_2011 (0.000135)
# 851. Median age (years)_male_2012 (0.000135)
# 852. Civilian_labor_force_2004 (0.000134)
# 853. 20000_to_24999_occupied_housing_units_2020 (0.000134)
# 854. Female_Total_2016 (0.000134)
# 855. INDUSTRY_Other_services_except_public_administration_total_workers_2016 (0.000133)
# 856. 35000_to_49999_occupied_housing_units_2012 (0.000132)
# 857. civilian_population_25_years_and_over_nonveterans_2012 (0.000131)
# 858. Unemployed_2012 (0.000131)
# 859. Population_25_to_64_years_Total_2016 (0.000129)
# 860. INDUSTRY_Retail_trade_total_workers_2016 (0.000129)
# 861. 20_to_29_percent_renter_occupied_housing_units_2012 (0.000128)
# 862. 60 years and over_total_2016 (0.000128)
# 863. 55 to 59 years_male_2016 (0.000127)
# 864. Unemployed_2000 (0.000125)
# 865. High_school_graduate_includes_equivalency_Total_2016 (0.000125)
# 866. High_school_graduate_includes_equivalency_employed_2016 (0.000125)
# 867. civilian_population_18_years_and_over_for_whom_poverty_status_is_determined_total_2012 (0.000125)
# 868. Unemployed_2014 (0.000124)
# 869. With_own_children_under_6_years_only_Total_2016 (0.000123)
# 870. 75_years_and_over_veterans_2016 (0.000123)
# 871. INDUSTRY_Construction_total_workers_2012 (0.000122)
# 872. Employed_2016 (0.000121)
# 873. Under 5 years_total_2016 (0.000121)
# 874. less_than_100_occupied_housing_units_2012 (0.000121)
# 875. 50 to 54 years_total_2016 (0.000120)
# 876. 55_to_59_years_employed_2016 (0.000117)
# 877. Male_Total_2012 (0.000117)
# 878. At_or_above_the_poverty_level_Total_2016 (0.000117)
# 879. civilian_population_18_years_and_over_total_2012 (0.000116)
# 880. 2500_to_2999_renter_occupied_housing_units_2016 (0.000115)
# 881. civilian_population_18_to_64_years_nonveterans_2016 (0.000114)
# 882. Employed_2012 (0.000112)
# 883. Median age (years)_female_2012 (0.000112)
# 884. 25000_to_34999_occupied_housing_units_2012 (0.000112)
# 885. bachelor's_degree_or_higher_veterans_2016 (0.000112)
# 886. without_a_disability_veterans_2016 (0.000112)
# 887. 35 to 39 years_male_2012 (0.000109)
# 888. occupied_housing_units_occupied_housing_units_2012 (0.000106)
# 889. 35_to_54_years_nonveterans_2016 (0.000104)
# 890. 55_to_64_years_nonveterans_2016 (0.000102)
# 891. Population_16_years_and_over_Total_2012 (0.000101)
# 892. 20000_to_34999_owner_occupied_housing_units_2012 (0.000100)
# 893. 35_to_44_years_employed_2016 (0.000097)
# 894. Employed_2014 (0.000092)
# 895. native_hawaiian_and_other_pacific_islander_total_2012 (0.000092)
# 896. zero_or_negative_income_owner_occupied_housing_units_2016 (0.000091)
# 897. Total population_female_2012 (0.000082)
# 898. INDUSTRY_Public_administration_pct_production_transportation_material_moving_occupations_2012 (0.000081)
# 899. some_college_or_associate's_degree_total_2016 (0.000079)
# 900. Employed_2004 (0.000079)
# 901. some_college_or_associate's_degree_nonveterans_2016 (0.000074)
# 902. Employed_2007 (0.000073)
# 903. Employed_2013 (0.000069)
# 904. native_hawaiian_and_other_pacific_islander_veterans_2012 (0.000069)
# 905. Total population_male_2016 (0.000066)
# 906. 15 to 17 years_female_2012 (0.000066)
# 907. 65 to 69 years_total_2016 (0.000065)
# 908. Civilian_labor_force_2015 (0.000062)
# 909. Employed_2006 (0.000059)
# 910. 35_to_44_years_Total_2016 (0.000057)
# 911. 30 to 34 years_total_2016 (0.000055)
# 912. Civilian_labor_force_2008 (0.000052)
# 913. civilian_labor_force_18_to_64_years_total_2016 (0.000049)
# 914. female_nonveterans_2016 (0.000049)
# 915. civilian_population_18_years_and_over_for_whom_poverty_status_is_determined_total_2016 (0.000038)
# 916. Population_20_to_64_years_Total_2016 (0.000037)
# 917. Employed_2005 (0.000035)
# 918. civilian_population_18_years_and_over_nonveterans_2012 (0.000034)
# 919. With_any_disability_Total_2016 (0.000029)
# 920. civilian_population_18_to_64_years_total_2012 (0.000028)
# 921. civilian_labor_force_18_to_64_years_total_2012 (0.000023)
# 922. native_hawaiian_and_other_pacific_islander_alone_veterans_2016 (0.000004)
# 923. Employed_2010 (0.000000)

# %%
# find the most common first node amongst all the decision trees
first_nodes = [estimator.tree_.feature[0] for estimator in rf.estimators_]
first_nodes = [node for node in first_nodes if node != -2]
first_nodes = pd.Series(first_nodes)
first_nodes.value_counts()
# Out:
# 791    5
# 767    4
# 792    4
# 793    4
# 92     4
#       ..
# 819    1
# 770    1
# 778    1
# 49     1
# 306    1
# Length: 64, dtype: int64

# %%
from sklearn.tree import export_graphviz

# Export as dot file
export_graphviz(rf.estimators_[0], out_file='tree.dot', 
                feature_names = X.columns,
                class_names = ['GOP', 'DEM'],
                rounded = True, proportion = False, 
                precision = 2, filled = True)

# Convert to png using system command (requires Graphviz)
from subprocess import call
call(['dot', '-Tpng', 'tree.dot', '-o', 'tree.png', '-Gdpi=600'])
# Out:
# 0

# %%
# gridsearch tuning and cross validation
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, 30, 40, 50]
}

rf = RandomForestClassifier()
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)

# print the best parameters
print(grid_search.best_params_)

# print the best score
print(grid_search.best_score_)

# print the accuracy of the model
y_pred = grid_search.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
