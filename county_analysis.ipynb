# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd

pd.set_option('display.max_columns', None)

# %%
# read the elections demographic data from the geojson file
elections_demographics = gpd.read_file('data/election/final_data/county_data_with_elections_2012_2016_2020.geojson')

# %%
elections_demographics_data = elections_demographics.drop(columns=['geometry'])

# %%
elections_demographics_data = pd.DataFrame(elections_demographics_data)

# %%
elections_demographics_data
# Out:
#      state_abbr  total_votes_2012  votes_dem_2012  votes_gop_2012  \
# 0            AL           23909.0          6354.0         17366.0
# 1            AL           84988.0         18329.0         65772.0
# 2            AL           11459.0          5873.0          5539.0
# 3            AL            8391.0          2200.0          6131.0
# 4            AL           23980.0          2961.0         20741.0
# ...         ...               ...             ...             ...
# 3101         WY           16750.0          4773.0         11427.0
# 3102         WY           11356.0          6211.0          4858.0
# 3103         WY            8453.0          1628.0          6613.0
# 3104         WY            3911.0           794.0          3013.0
# 3105         WY            3323.0           422.0          2821.0
#
#       per_dem_2012  per_gop_2012  diff_2012  per_point_diff_2012 FIPS Code  \
# 0         0.265758      0.726337    11012.0            -0.460580      1001
# ...
